# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import random
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
MyData = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
MyData
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 19703      NaN  International  2020-02-28          705          0
# 19704      NaN  International  2020-02-29          705          0
# 19705      NaN  International  2020-03-01          705          0
# 19706      NaN  International  2020-03-02          705          0
# 19707      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
MyData.sample(20)
# Out:
#       iso_code                  location        date  total_cases  new_cases  \
# 12997      MWI                    Malawi  2020-04-04            3          0
# 4646       DEU                   Germany  2020-05-07       166091       1194
# 12177      MEX                    Mexico  2020-05-14        40186       1862
# 18884      VGB    British Virgin Islands  2020-04-12            3          0
# 13504      NGA                   Nigeria  2020-04-24          981        108
# 16703      STP     Sao Tome and Principe  2020-05-12          212          4
# 6651       GBR            United Kingdom  2020-05-07       201201       6211
# 6779       GEO                   Georgia  2020-04-21          402          8
# 14862      POL                    Poland  2020-03-22          536        111
# 3009       CAF  Central African Republic  2020-05-07           94          0
# 10021      KGZ                Kyrgyzstan  2020-03-28           58         14
# ...

# %%
MyData.T
# Out:
#                                       0           1           2      \
# iso_code                                ABW         ABW         ABW
# location                              Aruba       Aruba       Aruba
# date                             2020-03-13  2020-03-20  2020-03-24
# total_cases                               2           4          12
# new_cases                                 2           2           8
# total_deaths                              0           0           0
# new_deaths                                0           0           0
# total_cases_per_million              18.733      37.465     112.395
# new_cases_per_million                18.733      18.733       74.93
# total_deaths_per_million                  0           0           0
# new_deaths_per_million                    0           0           0
# total_tests                             NaN         NaN         NaN
# new_tests                               NaN         NaN         NaN
# ...

# %%
MyData.isnull().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14544
# new_tests                          15116
# total_tests_per_thousand           14544
# new_tests_per_thousand             15116
# new_tests_smoothed                 14078
# new_tests_smoothed_per_thousand    14078
# tests_units                        13479
# stringency_index                    4571
# population                            64
# population_density                   862
# median_age                          1767
# aged_65_older                       2007
# ...

# %%
len(MyData)
# Out:
# 19708

# %%
MyData.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
MyData.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.970800e+04   19708.000000   19708.000000  19708.000000
# mean   1.789629e+04     545.128882    1186.842602     34.992389
# std    1.843281e+05    4886.065724   12583.269845    333.793785
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.600000e+01       2.000000       1.000000      0.000000
# 75%    1.163000e+03      44.000000      25.000000      1.000000
# max    5.371700e+06  107909.000000  344815.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19331.000000           19331.000000
# mean                507.076705              13.339908
# std                1474.006311              63.591455
# min                   0.000000            -265.189000
# 25%                   0.647000               0.000000
# 50%                  27.963000               0.251000
# ...

# %%
sns.heatmap(MyData.isnull(),yticklabels=False,cbar=False,cmap='cividis')

# %%
MyData["total_tests"].fillna('-1', inplace = True)
MyData["new_tests_per_thousand"].fillna('-1', inplace = True)
MyData["new_deaths_per_million"].fillna('-1', inplace = True)
MyData["new_tests"].fillna('-1', inplace = True)
MyData["iso_code"].fillna('-1', inplace = True)
MyData["population_density"].fillna('-1', inplace = True)
MyData["aged_65_older"].fillna('-1', inplace = True)
MyData["aged_70_older"].fillna('-1', inplace = True)
MyData["gdp_per_capita"].fillna('-1', inplace = True)
MyData["extreme_poverty"].fillna('-1', inplace = True)
MyData["cvd_death_rate"].fillna('-1', inplace = True)
MyData["diabetes_prevalence"].fillna('-1', inplace = True)
MyData["female_smokers"].fillna('-1', inplace = True)
MyData["male_smokers"].fillna('-1', inplace = True)
MyData["handwashing_facilities"].fillna('-1', inplace = True)
MyData["hospital_beds_per_100k"].fillna('-1', inplace = True)

# %%
MyData.sample(50)
# Out:
#        iso_code                      location        date  total_cases  \
# 4955        DOM            Dominican Republic  2020-01-11            0
# 15985       SEN                       Senegal  2020-03-28          119
# 19478       ZWE                      Zimbabwe  2020-05-07           34
# 16502       SOM                       Somalia  2020-04-28          480
# 16209       SLE                  Sierra Leone  2020-04-19           30
# 14728       PHL                   Philippines  2020-04-07         3660
# 32          ABW                         Aruba  2020-04-24          100
# 10057       KGZ                    Kyrgyzstan  2020-05-03          795
# 697         ARG                     Argentina  2020-05-25        12063
# 19616  OWID_WRL                         World  2020-04-28      2983864
# 17884       TUN                       Tunisia  2020-03-27          173
# 18333       UKR                       Ukraine  2020-04-18         5106
# ...

# %%
MyData = MyData.drop(["iso_code","location","total_cases_per_million","new_cases_per_million","total_deaths_per_million","new_deaths_per_million","total_tests_per_thousand","tests_units", ],axis=1)

# %%
MyData.sample(15)
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths  \
# 17336  2020-05-02           44          1             3           0
# 12608  2020-03-23           10          0             0           0
# 15669  2020-03-23          438        132             0           0
# 1385   2020-05-19           42          0             1           0
# 17980  2020-04-19        82329       3783          1890         121
# 3761   2020-05-15         1298         56            50           0
# 9226   2020-01-25            0          0             0           0
# 2196   2020-01-10            0          0             0           0
# 8450   2020-05-06          326          1            23           0
# 9816   2020-04-15         8100        455           119          10
# 14212  2020-01-22            0          0             0           0
# 12096  2020-02-23            0          0             0           0
# 17645  2020-03-30         1388        143             7           1
# ...

# %%
import seaborn as sns
import copy
sns.set()

# %%
MyData.columns.values
# Out:
# array(['date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'total_tests', 'new_tests', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'stringency_index', 'population', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'extreme_poverty', 'cvd_death_rate', 'diabetes_prevalence',
#        'female_smokers', 'male_smokers', 'handwashing_facilities',
#        'hospital_beds_per_100k'], dtype=object)

# %%
sns.lineplot(x='population', y='total_cases', data=MyData)

# %%
sns.lineplot(x='population', y='total_deaths', data=MyData)

# %%
sns.lineplot(x='population', y='new_cases', data=MyData)

# %%
sns.lineplot(x='population', y='new_deaths', data=MyData)

# %%
sns.catplot('total_cases', 'total_deaths', hue='new_deaths',height=4,aspect=2,data=MyData)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1013         try:
# -> 1014             self._set_with_engine(key, value)
#    1015         except com.SettingWithCopyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1053         try:
# -> 1054             self.index._engine.set_value(values, key, value)
#    1055             return
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '3427     False
# 6797     False
# 8211     False
# 16443    False
# 17897    False
# Name: new_deaths, dtype: bool' is an invalid key
#
# ...

# %%
import pandas as pd
import numpy as np
MyData=pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv",header="infer")
from collections import Counter

# %%
MyData.sample(20)
# Out:
#       iso_code        location        date  total_cases  new_cases  \
# 5650       ESP           Spain  2020-02-15            2          0
# 12617      MNG        Mongolia  2020-04-01           12          0
# 7591       GTM       Guatemala  2020-04-03           47          1
# 7463       GRD         Grenada  2020-04-14           14          0
# 1530       BEL         Belgium  2020-05-17        54989        345
# 2191       BLR         Belarus  2020-01-05            0          0
# 14580      PER            Peru  2020-04-02         1323        258
# 14058      NZL     New Zealand  2020-01-13            0          0
# 2400       BMU         Bermuda  2020-03-24            6          0
# 3107       CAN          Canada  2020-03-19          690        121
# 11043      LIE   Liechtenstein  2020-05-14           83          0
# 16180      SGP       Singapore  2020-05-15        26098        752
# 13941      NPL           Nepal  2020-02-12            1          0
# ...

# %%
classes = Counter(MyData['new_cases'].values)
classes.most_common()
# Out:
# [(0, 8292),
#  (1, 1106),
#  (2, 672),
#  (3, 450),
#  (4, 377),
#  (6, 298),
#  (5, 291),
#  (8, 215),
#  (7, 215),
#  (9, 198),
#  (10, 193),
#  (11, 163),
#  (12, 148),
#  (15, 138),
#  (13, 133),
#  (14, 122),
#  (17, 105),
#  (16, 104),
#  (19, 95),
#  (18, 92),
#  (21, 86),
#  (22, 85),
#  (20, 82),
#  (27, 71),
#  (28, 66),
#  (26, 65),
#  (30, 63),
#  (23, 63),
#  (25, 62),
#  (29, 61),
#  (36, 60),
#  (34, 59),
#  (39, 54),
#  (35, 53),
#  (24, 52),
#  (31, 52),
#  (32, 48),
#  (38, 47),
#  (33, 46),
#  (48, 44),
#  (43, 43),
#  (37, 38),
#  (45, 37),
#  (55, 36),
#  (50, 35),
#  (57, 35),
#  (51, 34),
#  (49, 33),
#  (40, 33),
#  (46, 33),
#  (54, 33),
#  (52, 32),
#  (44, 32),
#  (41, 31),
#  (42, 31),
#  (65, 31),
#  (69, 30),
#  (47, 30),
#  (76, 30),
#  (73, 29),
#  (78, 29),
#  (71, 28),
#  (62, 28),
#  (59, 28),
#  (64, 28),
#  (67, 27),
#  (70, 25),
#  (58, 23),
#  (63, 23),
#  (68, 23),
#  (53, 22),
#  (66, 22),
#  (56, 21),
#  (85, 21),
#  (61, 20),
#  (72, 20),
# ...

# %%
class_dist=pd.DataFrame(classes.most_common(),columns=['Class','new_cases'])

# %%
MyData.rename(columns={"new_cases":"Class"},inplace=True)
MyData["new_cases"]=MyData["Class"].map({-1:0,1:1})
MyData["Class"].unique()
# Out:
# array([     2,      8,      5, ..., 106570, 101131,  94633], dtype=int64)

# %%
MyData.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# Class                                  0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14421
# new_tests                          15009
# total_tests_per_thousand           14421
# new_tests_per_thousand             15009
# new_tests_smoothed                 13923
# new_tests_smoothed_per_thousand    13923
# tests_units                        13324
# stringency_index                    4490
# population                            64
# population_density                   862
# median_age                          1767
# aged_65_older                       2007
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=MyData.iloc[:,0:1617].values.astype(int)
y=yData.iloc[:,1].values.astype(int)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.random.seed(7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-599694e5c876> in <module>
# ----> 1 x=MyData.iloc[:,0:1617].values.astype(int)
#       2 y=yData.iloc[:,1].values.astype(int)
#       3 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.random.seed(7))
#
# ValueError: invalid literal for int() with base 10: 'ABW'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
subplot=class_dist.groupby("Class")["population"].sum().plot(kind="line",figsize=(15,5))
subplot.set_xlabel("new_cases",fontsize=15)
subplot.set_ylabel("Class",fontsize=14)
for i in subplot.patches:subplot.text(i.get_width()+0.5,i.get_y()+0.5, str(i.get_width()),fontsize=11)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-ebbad7c20756> in <module>
# ----> 1 subplot=class_dist.groupby("Class")["population"].sum().plot(kind="line",figsize=(15,5))
#       2 subplot.set_xlabel("new_cases",fontsize=15)
#       3 subplot.set_ylabel("Class",fontsize=14)
#       4 for i in subplot.patches:subplot.text(i.get_width()+0.5,i.get_y()+0.5, str(i.get_width()),fontsize=11)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     237         else:
#     238             if key not in self.obj:
# ...

# %%
MyData.columns.values
# Out:
# array(['iso_code', 'location', 'date', 'total_cases', 'Class',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_units', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k',
#        'new_cases'], dtype=object)

# %%
x = MyData.iloc[:, :1].values
y = MyData.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2,random_state=np.random.seed(7))

# %%
x
# Out:
# array([['ABW'],
#        ['ABW'],
#        ['ABW'],
#        ...,
#        [nan],
#        [nan],
#        [nan]], dtype=object)

# %%
x_train
# Out:
# array([['SYR'],
#        ['LUX'],
#        ['AGO'],
#        ...,
#        ['ESP'],
#        ['LBN'],
#        ['SVN']], dtype=object)

# %%
y_train
# Out:
# array([ 1., nan, nan, ..., nan, nan, nan])

# %%
from sklearn.metrics import accuracy_score,precision_recall_fscore_support,classification_report
from sklearn.linear_model import LogisticRegression
import wandb
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-4efc6fc9c218> in <module>
#       1 from sklearn.metrics import accuracy_score,precision_recall_fscore_support,classification_report
#       2 from sklearn.linear_model import LogisticRegression
# ----> 3 import wandb
#       4 import time
#
# ModuleNotFoundError: No module named 'wandb'

# %%
MyData.describe()
# Out:
#         total_cases          Class   total_deaths    new_deaths  \
# count  1.970800e+04   19708.000000   19708.000000  19708.000000
# mean   1.789629e+04     545.128882    1186.842602     34.992389
# std    1.843281e+05    4886.065724   12583.269845    333.793785
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.600000e+01       2.000000       1.000000      0.000000
# 75%    1.163000e+03      44.000000      25.000000      1.000000
# max    5.371700e+06  107909.000000  344815.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19331.000000           19331.000000
# mean                507.076705              13.339908
# std                1474.006311              63.591455
# min                   0.000000            -265.189000
# 25%                   0.647000               0.000000
# 50%                  27.963000               0.251000
# ...

# %%
pip install wandb
# Out:
# ...
#   Using cached wandb-0.8.36-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached gql-0.2.0.tar.gz (18 kB)
# ...
#   Using cached GitPython-3.1.2-py3-none-any.whl (451 kB)
# ...
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# ...
#   Using cached configparser-5.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached sentry_sdk-0.14.4-py2.py3-none-any.whl (104 kB)
# ...
#   Using cached subprocess32-3.5.4.tar.gz (97 kB)
# ...
#   Using cached nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# ...
#   Using cached shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# ...
#   Using cached graphql-core-1.1.tar.gz (70 kB)
# ...
#   Using cached promise-2.3.tar.gz (19 kB)
# ...
#   Using cached gitdb-4.0.5-py3-none-any.whl (63 kB)
# ...
#   Using cached smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# ...
#   Created wheel for gql: filename=gql-0.2.0-py3-none-any.whl size=7633 sha256=22bdb0b9df61ddef3a8cde2b73378fbbf2f629ada2ba4b615dd619c8af851251
# ...

# %%
from sklearn.metrics import accuracy_score,precision_recall_fscore_support,classification_report
from sklearn.linear_model import LogisticRegression
import wandb
import time

# %%
MyData.describe()
# Out:
#         total_cases          Class   total_deaths    new_deaths  \
# count  1.970800e+04   19708.000000   19708.000000  19708.000000
# mean   1.789629e+04     545.128882    1186.842602     34.992389
# std    1.843281e+05    4886.065724   12583.269845    333.793785
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.600000e+01       2.000000       1.000000      0.000000
# 75%    1.163000e+03      44.000000      25.000000      1.000000
# max    5.371700e+06  107909.000000  344815.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19331.000000           19331.000000
# mean                507.076705              13.339908
# std                1474.006311              63.591455
# min                   0.000000            -265.189000
# 25%                   0.647000               0.000000
# 50%                  27.963000               0.251000
# ...
